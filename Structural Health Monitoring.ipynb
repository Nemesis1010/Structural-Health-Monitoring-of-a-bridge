# %% [markdown]
# # PROJECT B

# %% [markdown]
# # Step 1: Import necessary functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, accuracy_score,  mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Step 2: Load all data

# %%
Perfect_1_e_5000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_5000N\Deformation_X_axis.csv")
Perfect_1_e_5000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_5000N\Deformation_Y_axis.csv")
Perfect_1_e_5000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_5000N\Deformation_Z_axis.csv")
Perfect_1_e_5000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_5000N\Shear Stress XY.csv")
Perfect_1_e_5000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_5000N\Shear Stress XZ.csv")
Perfect_1_e_5000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_5000N\Shear Stress YZ.csv")
Perfect_1_e_5000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_5000N\Total Deformation.csv")

Perfect_1_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_2000N\Deformation_X_axis.csv")
Perfect_1_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_2000N\Deformation_Y_axis.csv")
Perfect_1_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_2000N\Deformation_Z_axis.csv")
Perfect_1_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_2000N\Shear Stress XY.csv")
Perfect_1_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_2000N\Shear Stress XZ.csv")
Perfect_1_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_2000N\Shear Stress YZ.csv")
Perfect_1_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_extreme_track_2000N\Total Deformation.csv")

Perfect_1_m_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_middle_track_2000N\Deformation_X_axis.csv")
Perfect_1_m_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_middle_track_2000N\Deformation_Y_axis.csv")
Perfect_1_m_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_middle_track_2000N\Deformation_Z_axis.csv")
Perfect_1_m_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_middle_track_2000N\Shear Stress XY.csv")
Perfect_1_m_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_middle_track_2000N\Shear Stress XZ.csv")
Perfect_1_m_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_middle_track_2000N\Shear Stress YZ.csv")
Perfect_1_m_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_1_train_middle_track_2000N\Total Deformation.csv")

Perfect_2_o_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_X_axis.csv")
Perfect_2_o_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_Y_axis.csv")
Perfect_2_o_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_Z_axis.csv")
Perfect_2_o_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress XY.csv")
Perfect_2_o_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress XZ.csv")
Perfect_2_o_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress YZ.csv")
Perfect_2_o_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Perfect_Structure_data\Perfect_structure_2_trains_opposite_direction_extreme_tracks_2000N\Total_deformation.csv")

Imperfect_1_1_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_2000N\Deformation_X_axis.csv")
Imperfect_1_1_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_2000N\Deformation_Y_axis.csv")
Imperfect_1_1_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_2000N\Deformation_Z_axis.csv")
Imperfect_1_1_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_2000N\Shear Stress XY.csv")
Imperfect_1_1_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_2000N\Shear Stress XZ.csv")
Imperfect_1_1_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_2000N\Shear Stress YZ.csv")
Imperfect_1_1_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_2000N\Total Deformation.csv")

Imperfect_1_1_e_5000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_5000N\Deformation_X_axis.csv")
Imperfect_1_1_e_5000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_5000N\Deformation_Y_axis.csv")
Imperfect_1_1_e_5000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_5000N\Deformation_Z_axis.csv")
Imperfect_1_1_e_5000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_5000N\Shear Stress XY.csv")
Imperfect_1_1_e_5000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_5000N\Shear Stress XZ.csv")
Imperfect_1_1_e_5000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_5000N\Shear Stress YZ.csv")
Imperfect_1_1_e_5000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_1_train_extreme_track_5000N\Total Deformation.csv")

Imperfect_1_2_o_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_2_trains_opposite_direction_extreme_track_2000N\Deformation_X_axis.csv")
Imperfect_1_2_o_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_2_trains_opposite_direction_extreme_track_2000N\Deformation_Y_axis.csv")
Imperfect_1_2_o_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_2_trains_opposite_direction_extreme_track_2000N\Deformation_Z_axis.csv")
Imperfect_1_2_o_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_2_trains_opposite_direction_extreme_track_2000N\Shear Stress XY.csv")
Imperfect_1_2_o_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_2_trains_opposite_direction_extreme_track_2000N\Shear Stress XZ.csv")
Imperfect_1_2_o_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_2_trains_opposite_direction_extreme_track_2000N\Shear Stress YZ.csv")
Imperfect_1_2_o_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_1_2_trains_opposite_direction_extreme_track_2000N\Total Deformation.csv")

Imperfect_2_1_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_1_train_extreme_track_2000N\Deformation_X_axis.csv")
Imperfect_2_1_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_1_train_extreme_track_2000N\Deformation_Y_axis.csv")
Imperfect_2_1_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_1_train_extreme_track_2000N\Deformation_Z_axis.csv")
Imperfect_2_1_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_1_train_extreme_track_2000N\Shear Stress XY.csv")
Imperfect_2_1_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_1_train_extreme_track_2000N\Shear Stress XZ.csv")
Imperfect_2_1_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_1_train_extreme_track_2000N\Shear Stress YZ.csv")
Imperfect_2_1_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_1_train_extreme_track_2000N\Total Deformation.csv")

Imperfect_2_1_e_5000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_2_1_train_extreme_Track_5000N\Deformation_X_axis.csv")
Imperfect_2_1_e_5000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_2_1_train_extreme_Track_5000N\Deformation_Y_axis.csv")
Imperfect_2_1_e_5000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_2_1_train_extreme_Track_5000N\Deformation_Z_axis.csv")
Imperfect_2_1_e_5000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_2_1_train_extreme_Track_5000N\Shear Stress XY.csv")
Imperfect_2_1_e_5000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_2_1_train_extreme_Track_5000N\Shear Stress XZ.csv")
Imperfect_2_1_e_5000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_2_1_train_extreme_Track_5000N\Shear Stress YZ.csv")
Imperfect_2_1_e_5000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_2_1_train_extreme_Track_5000N\Total Deformation.csv")

Imperfect_2_2_o_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_2_trains_opposite_direction_Extreme_tracks_2000N\Deformation_X_axis.csv")
Imperfect_2_2_o_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_2_trains_opposite_direction_Extreme_tracks_2000N\Deformation_Y_axis.csv")
Imperfect_2_2_o_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_2_trains_opposite_direction_Extreme_tracks_2000N\Deformation_Z_axis.csv")
Imperfect_2_2_o_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_2_trains_opposite_direction_Extreme_tracks_2000N\Shear Stress XY.csv")
Imperfect_2_2_o_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_2_trains_opposite_direction_Extreme_tracks_2000N\Shear Stress XZ.csv")
Imperfect_2_2_o_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_2_trains_opposite_direction_Extreme_tracks_2000N\Shear Stress YZ.csv")
Imperfect_2_2_o_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_2_2_trains_opposite_direction_Extreme_tracks_2000N\Total Deformation.csv")

Imperfect_3_1_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_1_train_extreme_track_2000N\Deformation_X_axis.csv")
Imperfect_3_1_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_1_train_extreme_track_2000N\Deformation_Y_axis.csv")
Imperfect_3_1_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_1_train_extreme_track_2000N\Deformation_Z_axis.csv")
Imperfect_3_1_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_1_train_extreme_track_2000N\Shear Stress XY.csv")
Imperfect_3_1_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_1_train_extreme_track_2000N\Shear Stress XZ.csv")
Imperfect_3_1_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_1_train_extreme_track_2000N\Shear Stress YZ.csv")
Imperfect_3_1_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_1_train_extreme_track_2000N\Total Deformation.csv")

Imperfect_3_1_e_5000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_3_1_train_extreme_track_5000N\Deformation_X_axis.csv")
Imperfect_3_1_e_5000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_3_1_train_extreme_track_5000N\Deformation_Y_axis.csv")
Imperfect_3_1_e_5000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_3_1_train_extreme_track_5000N\Deformation_Z_axis.csv")
Imperfect_3_1_e_5000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_3_1_train_extreme_track_5000N\Shear Stress XY.csv")
Imperfect_3_1_e_5000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_3_1_train_extreme_track_5000N\Shear Stress XZ.csv")
Imperfect_3_1_e_5000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_3_1_train_extreme_track_5000N\Shear Stress YZ.csv")
Imperfect_3_1_e_5000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_3_1_train_extreme_track_5000N\Total Deformation.csv")

Imperfect_3_2_o_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_X_axis.csv")
Imperfect_3_2_o_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_Y_axis.csv")
Imperfect_3_2_o_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_Z_axis.csv")
Imperfect_3_2_o_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress XY.csv")
Imperfect_3_2_o_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress XZ.csv")
Imperfect_3_2_o_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress YZ.csv")
Imperfect_3_2_o_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_3_2_trains_opposite_direction_extreme_tracks_2000N\Total Deformation.csv")

Imperfect_4_1_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_2000N\Deformation_X_axis.csv")
Imperfect_4_1_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_2000N\Deformation_Y_axis.csv")
Imperfect_4_1_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_2000N\Deformation_Z_axis.csv")
Imperfect_4_1_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_2000N\Shear Stress XY.csv")
Imperfect_4_1_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_2000N\Shear Stress XZ.csv")
Imperfect_4_1_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_2000N\shear Stress YZ.csv")
Imperfect_4_1_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_2000N\Total Deformation.csv")

Imperfect_4_1_e_5000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_5000N\Deformation_X_axis.csv")
Imperfect_4_1_e_5000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_5000N\Deformation_Y_axis.csv")
Imperfect_4_1_e_5000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_5000N\Deformation_Z_axis.csv")
Imperfect_4_1_e_5000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_5000N\Shear Stress XY.csv")
Imperfect_4_1_e_5000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_5000N\Shear Stress XZ.csv")
Imperfect_4_1_e_5000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_5000N\Shear Stress YZ.csv")
Imperfect_4_1_e_5000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_4_1_train_extreme_track_5000N\Total Deformation.csv")

Imperfect_4_2_o_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_4_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_X_axis.csv")
Imperfect_4_2_o_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_4_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_Y_axis.csv")
Imperfect_4_2_o_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_4_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_Z_axis.csv")
Imperfect_4_2_o_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_4_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress XY.csv")
Imperfect_4_2_o_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_4_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress XZ.csv")
Imperfect_4_2_o_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_4_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress YZ.csv")
Imperfect_4_2_o_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_4_2_trains_opposite_direction_extreme_tracks_2000N\Total Deformation.csv")


Imperfect_5_1_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_2000N\Deformation_X_axis.csv")
Imperfect_5_1_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_2000N\Deformation_Y_axis.csv")
Imperfect_5_1_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_2000N\Deformation_Z_axis.csv")
Imperfect_5_1_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_2000N\Shear Stress XY.csv")
Imperfect_5_1_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_2000N\Shear Stress XZ.csv")
Imperfect_5_1_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_2000N\Shear Stress YZ.csv")
Imperfect_5_1_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_2000N\Total Deformation.csv")

Imperfect_5_1_e_5000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_5000N\Deformation_X_axis.csv")
Imperfect_5_1_e_5000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_5000N\Deformation_Y_axis.csv")
Imperfect_5_1_e_5000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_5000N\Deformation_Z_axis.csv")
Imperfect_5_1_e_5000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_5000N\Shear Stress XY.csv")
Imperfect_5_1_e_5000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_5000N\Shear Stress XZ.csv")
Imperfect_5_1_e_5000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_5000N\Shear Stress YZ.csv")
Imperfect_5_1_e_5000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\imperfect_no_5_1_train_extreme_track_5000N\Total Deformation.csv")

Imperfect_5_2_o_e_2000_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_5_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_X_axis.csv")
Imperfect_5_2_o_e_2000_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_5_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_Y_axis.csv")
Imperfect_5_2_o_e_2000_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_5_2_trains_opposite_direction_extreme_tracks_2000N\Deformation_Z_axis.csv")
Imperfect_5_2_o_e_2000_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_5_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress XY.csv")
Imperfect_5_2_o_e_2000_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_5_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress XZ.csv")
Imperfect_5_2_o_e_2000_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_5_2_trains_opposite_direction_extreme_tracks_2000N\Shear Stress YZ.csv")
Imperfect_5_2_o_e_2000_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Imperfect_no_5_2_trains_opposite_direction_extreme_tracks_2000N\Total Deformation.csv")

Test_Set_Imperfect_4_1_m_2000N_X = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Test_set\Imperfect_no_4_1_train_middle_track_2000N\Deformation_X_axis.csv")
Test_Set_Imperfect_4_1_m_2000N_Y = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Test_set\Imperfect_no_4_1_train_middle_track_2000N\Deformation_Y_axis.csv")
Test_Set_Imperfect_4_1_m_2000N_Z = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Test_set\Imperfect_no_4_1_train_middle_track_2000N\Deformation_Z_axis.csv")
Test_Set_Imperfect_4_1_m_2000N_XY = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Test_set\Imperfect_no_4_1_train_middle_track_2000N\Shear Stress XY.csv")
Test_Set_Imperfect_4_1_m_2000N_XZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Test_set\Imperfect_no_4_1_train_middle_track_2000N\Shear Stress XZ.csv")
Test_Set_Imperfect_4_1_m_2000N_YZ = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Test_set\Imperfect_no_4_1_train_middle_track_2000N\Shear Stress YZ.csv")
Test_Set_Imperfect_4_1_m_2000N_Total = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\RWTH UNIVERSITY COURSE\Semster 1 MOODLE\Computational Intelligence in Engineering\Project B\Imperfect_structure_Data\Test_set\Imperfect_no_4_1_train_middle_track_2000N\Total Deformation.csv")

# %% [markdown]
# # Step 3: Data Pre-Processing

# %%
#Horizontally concatenate all of the data that belongs to the same set
Perfect_1_e_5000 = pd.concat([Perfect_1_e_5000_X, Perfect_1_e_5000_Y, Perfect_1_e_5000_Z, Perfect_1_e_5000_XY, Perfect_1_e_5000_XZ, Perfect_1_e_5000_YZ, Perfect_1_e_5000_Total], axis=1)
Perfect_1_e_2000 = pd.concat([Perfect_1_e_2000_X, Perfect_1_e_2000_Y, Perfect_1_e_2000_Z, Perfect_1_e_2000_XY, Perfect_1_e_2000_XZ, Perfect_1_e_2000_YZ, Perfect_1_e_2000_Total], axis=1)
Perfect_1_m_2000 = pd.concat([Perfect_1_m_2000_X, Perfect_1_m_2000_Y, Perfect_1_m_2000_Z, Perfect_1_m_2000_XY, Perfect_1_m_2000_XZ, Perfect_1_m_2000_YZ, Perfect_1_m_2000_Total], axis=1)
Perfect_2_o_e_2000 = pd.concat([Perfect_2_o_e_2000_X, Perfect_2_o_e_2000_Y, Perfect_2_o_e_2000_Z, Perfect_2_o_e_2000_XY, Perfect_2_o_e_2000_XZ, Perfect_2_o_e_2000_YZ, Perfect_2_o_e_2000_Total], axis=1)
Imperfect_1_1_e_2000 = pd.concat([Imperfect_1_1_e_2000_X, Imperfect_1_1_e_2000_Y, Imperfect_1_1_e_2000_Z, Imperfect_1_1_e_2000_XY, Imperfect_1_1_e_2000_XZ, Imperfect_1_1_e_2000_YZ, Imperfect_1_1_e_2000_Total], axis=1)
Imperfect_1_1_e_5000 = pd.concat([Imperfect_1_1_e_5000_X, Imperfect_1_1_e_5000_Y, Imperfect_1_1_e_5000_Z, Imperfect_1_1_e_5000_XY, Imperfect_1_1_e_5000_XZ, Imperfect_1_1_e_5000_YZ, Imperfect_1_1_e_5000_Total], axis=1)
Imperfect_1_2_o_e_2000 = pd.concat([Imperfect_1_2_o_e_2000_X, Imperfect_1_2_o_e_2000_Y, Imperfect_1_2_o_e_2000_Z, Imperfect_1_2_o_e_2000_XY, Imperfect_1_2_o_e_2000_XZ, Imperfect_1_2_o_e_2000_YZ, Imperfect_1_2_o_e_2000_Total], axis=1)
Imperfect_2_1_e_2000 = pd.concat([Imperfect_2_1_e_2000_X, Imperfect_2_1_e_2000_Y, Imperfect_2_1_e_2000_Z, Imperfect_2_1_e_2000_XY, Imperfect_2_1_e_2000_XZ, Imperfect_2_1_e_2000_YZ, Imperfect_2_1_e_2000_Total], axis=1)
Imperfect_2_1_e_5000 = pd.concat([Imperfect_2_1_e_5000_X, Imperfect_2_1_e_5000_Y, Imperfect_2_1_e_5000_Z, Imperfect_2_1_e_5000_XY, Imperfect_2_1_e_5000_XZ, Imperfect_2_1_e_5000_YZ, Imperfect_2_1_e_5000_Total], axis=1)
Imperfect_2_2_o_e_2000 = pd.concat([Imperfect_2_2_o_e_2000_X, Imperfect_2_2_o_e_2000_Y, Imperfect_2_2_o_e_2000_Z, Imperfect_2_2_o_e_2000_XY, Imperfect_2_2_o_e_2000_XZ, Imperfect_2_2_o_e_2000_YZ, Imperfect_2_2_o_e_2000_Total], axis=1)
Imperfect_3_1_e_2000 = pd.concat([Imperfect_3_1_e_2000_X, Imperfect_3_1_e_2000_Y, Imperfect_3_1_e_2000_Z, Imperfect_3_1_e_2000_XY, Imperfect_3_1_e_2000_XZ, Imperfect_3_1_e_2000_YZ, Imperfect_3_1_e_2000_Total], axis=1)
Imperfect_3_1_e_5000 = pd.concat([Imperfect_3_1_e_5000_X, Imperfect_3_1_e_5000_Y, Imperfect_3_1_e_5000_Z, Imperfect_3_1_e_5000_XY, Imperfect_3_1_e_5000_XZ, Imperfect_3_1_e_5000_YZ, Imperfect_3_1_e_5000_Total], axis=1)
Imperfect_3_2_o_e_2000 = pd.concat([Imperfect_3_2_o_e_2000_X, Imperfect_3_2_o_e_2000_Y, Imperfect_3_2_o_e_2000_Z, Imperfect_3_2_o_e_2000_XY, Imperfect_3_2_o_e_2000_XZ, Imperfect_3_2_o_e_2000_YZ, Imperfect_3_2_o_e_2000_Total], axis=1)
Imperfect_4_1_e_2000 = pd.concat([Imperfect_4_1_e_2000_X, Imperfect_4_1_e_2000_Y, Imperfect_4_1_e_2000_Z, Imperfect_4_1_e_2000_XY, Imperfect_4_1_e_2000_XZ, Imperfect_4_1_e_2000_YZ, Imperfect_4_1_e_2000_Total], axis=1)
Imperfect_4_1_e_5000 = pd.concat([Imperfect_4_1_e_5000_X, Imperfect_4_1_e_5000_Y, Imperfect_4_1_e_5000_Z, Imperfect_4_1_e_5000_XY, Imperfect_4_1_e_5000_XZ, Imperfect_4_1_e_5000_YZ, Imperfect_4_1_e_5000_Total], axis=1)
Imperfect_4_2_o_e_2000 = pd.concat([Imperfect_4_2_o_e_2000_X, Imperfect_4_2_o_e_2000_Y, Imperfect_4_2_o_e_2000_Z, Imperfect_4_2_o_e_2000_XY, Imperfect_4_2_o_e_2000_XZ, Imperfect_4_2_o_e_2000_YZ, Imperfect_4_2_o_e_2000_Total], axis=1)
Imperfect_5_1_e_2000 = pd.concat([Imperfect_5_1_e_2000_X, Imperfect_5_1_e_2000_Y, Imperfect_5_1_e_2000_Z, Imperfect_5_1_e_2000_XY, Imperfect_5_1_e_2000_XZ, Imperfect_5_1_e_2000_YZ, Imperfect_5_1_e_2000_Total], axis=1)
Imperfect_5_1_e_5000 = pd.concat([Imperfect_5_1_e_5000_X, Imperfect_5_1_e_5000_Y, Imperfect_5_1_e_5000_Z, Imperfect_5_1_e_5000_XY, Imperfect_5_1_e_5000_XZ, Imperfect_5_1_e_5000_YZ, Imperfect_5_1_e_5000_Total], axis=1)
Imperfect_5_2_o_e_2000 = pd.concat([Imperfect_5_2_o_e_2000_X, Imperfect_5_2_o_e_2000_Y, Imperfect_5_2_o_e_2000_Z, Imperfect_5_2_o_e_2000_XY, Imperfect_5_2_o_e_2000_XZ, Imperfect_5_2_o_e_2000_YZ, Imperfect_5_2_o_e_2000_Total], axis=1)
Test_Set_Imperfect_4_1_m_2000N = pd.concat([Test_Set_Imperfect_4_1_m_2000N_X, Test_Set_Imperfect_4_1_m_2000N_Y, Test_Set_Imperfect_4_1_m_2000N_Z, Test_Set_Imperfect_4_1_m_2000N_XY, Test_Set_Imperfect_4_1_m_2000N_XZ, Test_Set_Imperfect_4_1_m_2000N_YZ, Test_Set_Imperfect_4_1_m_2000N_Total], axis=1)

#Remove duplicate columns i.e. node numbers
Perfect_1_e_5000 = Perfect_1_e_5000.loc[:, ~Perfect_1_e_5000.columns.duplicated()]
Perfect_1_e_2000 = Perfect_1_e_2000.loc[:, ~Perfect_1_e_2000.columns.duplicated()]
Perfect_1_m_2000 = Perfect_1_m_2000.loc[:, ~Perfect_1_m_2000.columns.duplicated()]
Perfect_2_o_e_2000 = Perfect_2_o_e_2000.loc[:, ~Perfect_2_o_e_2000.columns.duplicated()]
Imperfect_1_1_e_2000 = Imperfect_1_1_e_2000.loc[:, ~Imperfect_1_1_e_2000.columns.duplicated()]
Imperfect_1_1_e_5000 = Imperfect_1_1_e_5000.loc[:, ~Imperfect_1_1_e_5000.columns.duplicated()]
Imperfect_1_2_o_e_2000 = Imperfect_1_2_o_e_2000.loc[:, ~Imperfect_1_2_o_e_2000.columns.duplicated()]
Imperfect_2_1_e_2000 = Imperfect_2_1_e_2000.loc[:, ~Imperfect_2_1_e_2000.columns.duplicated()]
Imperfect_2_1_e_5000 = Imperfect_2_1_e_5000.loc[:, ~Imperfect_2_1_e_5000.columns.duplicated()]
Imperfect_2_2_o_e_2000 = Imperfect_2_2_o_e_2000.loc[:, ~Imperfect_2_2_o_e_2000.columns.duplicated()]
Imperfect_3_1_e_2000 = Imperfect_3_1_e_2000.loc[:, ~Imperfect_3_1_e_2000.columns.duplicated()]
Imperfect_3_1_e_5000 = Imperfect_3_1_e_5000.loc[:, ~Imperfect_3_1_e_5000.columns.duplicated()]
Imperfect_3_2_o_e_2000 = Imperfect_3_2_o_e_2000.loc[:, ~Imperfect_3_2_o_e_2000.columns.duplicated()]
Imperfect_4_1_e_2000 = Imperfect_4_1_e_2000.loc[:, ~Imperfect_4_1_e_2000.columns.duplicated()]
Imperfect_4_1_e_5000 = Imperfect_4_1_e_5000.loc[:, ~Imperfect_4_1_e_5000.columns.duplicated()]
Imperfect_4_2_o_e_2000 = Imperfect_4_2_o_e_2000.loc[:, ~Imperfect_4_2_o_e_2000.columns.duplicated()]
Imperfect_5_1_e_2000 = Imperfect_5_1_e_2000.loc[:, ~Imperfect_5_1_e_2000.columns.duplicated()]
Imperfect_5_1_e_5000 = Imperfect_5_1_e_5000.loc[:, ~Imperfect_5_1_e_5000.columns.duplicated()]
Imperfect_5_2_o_e_2000 = Imperfect_5_2_o_e_2000.loc[:, ~Imperfect_5_2_o_e_2000.columns.duplicated()]
Test_Set_Imperfect_4_1_m_2000N = Test_Set_Imperfect_4_1_m_2000N.loc[:, ~Test_Set_Imperfect_4_1_m_2000N.columns.duplicated()]

#Classify good nodes. This will be the 'y' for our model. 
Perfect_1_e_5000['Class'] = 0
Perfect_1_e_2000['Class'] = 0
Perfect_1_m_2000['Class'] = 0
Perfect_2_o_e_2000['Class'] = 0
Imperfect_1_1_e_2000['Class'] = 0
Imperfect_1_1_e_5000['Class'] = 0
Imperfect_1_2_o_e_2000['Class'] = 0
Imperfect_2_1_e_2000['Class'] = 0
Imperfect_2_1_e_5000['Class'] = 0
Imperfect_2_2_o_e_2000['Class'] = 0
Imperfect_3_1_e_2000['Class'] = 0
Imperfect_3_1_e_5000['Class'] = 0
Imperfect_3_2_o_e_2000['Class'] = 0 
Imperfect_4_1_e_2000['Class'] = 0
Imperfect_4_1_e_5000['Class'] = 0
Imperfect_4_2_o_e_2000['Class'] = 0 
Imperfect_5_1_e_2000['Class'] = 0
Imperfect_5_1_e_5000['Class'] = 0
Imperfect_5_2_o_e_2000['Class'] = 0
Test_Set_Imperfect_4_1_m_2000N['Class'] = 0

# %%
#Turn to arrays
Perfect_1_e_5000_arr = Perfect_1_e_5000.to_numpy().astype(float)
Perfect_1_e_2000_arr = Perfect_1_e_2000.to_numpy().astype(float)
Perfect_1_m_2000_arr = Perfect_1_m_2000.to_numpy().astype(float)
Perfect_2_o_e_2000_arr = Perfect_2_o_e_2000.to_numpy().astype(float)
Imperfect_1_1_e_2000_arr = Imperfect_1_1_e_2000.to_numpy().astype(float)
Imperfect_1_1_e_5000_arr = Imperfect_1_1_e_5000.to_numpy().astype(float)
Imperfect_1_2_o_e_2000_arr = Imperfect_1_2_o_e_2000.to_numpy().astype(float)
Imperfect_2_1_e_2000_arr = Imperfect_2_1_e_2000.to_numpy().astype(float)
Imperfect_2_1_e_5000_arr = Imperfect_2_1_e_5000.to_numpy().astype(float)
Imperfect_2_2_o_e_2000_arr = Imperfect_2_2_o_e_2000.to_numpy().astype(float)
Imperfect_3_1_e_2000_arr = Imperfect_3_1_e_2000.to_numpy().astype(float)
Imperfect_3_1_e_5000_arr = Imperfect_3_1_e_5000.to_numpy().astype(float)
Imperfect_3_2_o_e_2000_arr = Imperfect_3_2_o_e_2000.to_numpy().astype(float)
Imperfect_4_1_e_2000_arr = Imperfect_4_1_e_2000.to_numpy().astype(float)
Imperfect_4_1_e_5000_arr = Imperfect_4_1_e_5000.to_numpy().astype(float)
Imperfect_4_2_o_e_2000_arr = Imperfect_4_2_o_e_2000.to_numpy().astype(float)
Imperfect_5_1_e_2000_arr = Imperfect_5_1_e_2000.to_numpy().astype(float)
Imperfect_5_1_e_5000_arr = Imperfect_5_1_e_5000.to_numpy().astype(float)
Imperfect_5_2_o_e_2000_arr = Imperfect_5_2_o_e_2000.to_numpy().astype(float)
Test_Set_Imperfect_4_1_m_2000N_arr = Test_Set_Imperfect_4_1_m_2000N.to_numpy().astype(float)

# %%
#Function to fill in missing nodes. This simulates faulty data in imperfect structures. 
def fill(x):
    new_arr = np.zeros(shape=(29226, 80))
    i = 0
    for j in range(len(x)):
        if x[j,0] == i+1:
            new_arr[i] = x[j]
            i = i+1
        else:
            while i < x[j,0]:
                #Create a random array with values within the range of the x data.
                ran_arr = (10**-5)*random.rand(78)
                z = np.append(i+1, ran_arr)
                #Adding a 1 to the last column of this new node will serve to classify it as imperfect.
                new_arr[i] = np.append(z, 1)
                i = i + 1
    return new_arr

#Classify and fill in imperfect arrays
Imperfect_1_1_e_2000_arr_class = fill(Imperfect_1_1_e_2000_arr)
Imperfect_1_1_e_5000_arr_class = fill(Imperfect_1_1_e_5000_arr)
Imperfect_1_2_o_e_2000_arr_class = fill(Imperfect_1_2_o_e_2000_arr)
Imperfect_2_1_e_2000_arr_class = fill(Imperfect_2_1_e_2000_arr)
Imperfect_2_1_e_5000_arr_class = fill(Imperfect_2_1_e_5000_arr)
Imperfect_2_2_o_e_2000_arr_class = fill(Imperfect_2_2_o_e_2000_arr)
Imperfect_3_1_e_2000_arr_class = fill(Imperfect_3_1_e_2000_arr)
Imperfect_3_1_e_5000_arr_class = fill(Imperfect_3_1_e_5000_arr)
Imperfect_3_2_o_e_2000_arr_class = fill(Imperfect_3_2_o_e_2000_arr)
Imperfect_4_1_e_2000_arr_class = fill(Imperfect_4_1_e_2000_arr)
Imperfect_4_1_e_5000_arr_class = fill(Imperfect_4_1_e_5000_arr)
Imperfect_4_2_o_e_2000_arr_class = fill(Imperfect_4_2_o_e_2000_arr)
Imperfect_5_1_e_2000_arr_class = fill(Imperfect_5_1_e_2000_arr)
Imperfect_5_1_e_5000_arr_class = fill(Imperfect_5_1_e_5000_arr)
Imperfect_5_2_o_e_2000_arr_class = fill(Imperfect_5_2_o_e_2000_arr)
Test_Set_Imperfect_4_1_m_2000N_arr_class = fill(Test_Set_Imperfect_4_1_m_2000N_arr)

# %%
#Create a big array with all the Data
Perfect = np.vstack((Perfect_1_e_5000_arr, Perfect_1_e_2000_arr, Perfect_1_m_2000_arr, Perfect_2_o_e_2000_arr)).astype(float)
Imperfect = np.vstack((Imperfect_1_1_e_2000_arr_class, Imperfect_1_1_e_5000_arr_class, Imperfect_1_2_o_e_2000_arr_class, Imperfect_2_1_e_2000_arr_class, Imperfect_2_1_e_5000_arr_class, Imperfect_2_2_o_e_2000_arr_class, Imperfect_3_1_e_2000_arr_class, Imperfect_3_1_e_5000_arr_class, Imperfect_3_2_o_e_2000_arr_class, Imperfect_4_1_e_2000_arr_class, Imperfect_4_1_e_5000_arr_class, Imperfect_4_2_o_e_2000_arr_class, Imperfect_5_1_e_2000_arr_class, Imperfect_5_1_e_5000_arr_class, Imperfect_5_2_o_e_2000_arr_class)).astype(float)
#Big array does not include Test Set
big_array = np.vstack((Perfect, Imperfect))

# %% [markdown]
# # Step 4: Visualizing the Data

# %%
#Use a plot to confirm that random features are within range of perfect data
#Use plot to select features that might be useful to identify imperfect nodes
#plt.scatter(Perfect_1_e_5000_arr[:,0], Perfect_1_e_5000_arr[:,64], color='green', marker='+')
plt.scatter(Imperfect_1_1_e_5000_arr_class[:,0], Imperfect_1_1_e_5000_arr_class[:,64], color='red', marker='.')
plt.xlabel("Node Number")
plt.ylabel("Shear Stress (MPa)")
plt.title("Perfect Structure")
plt.title("Imperfect Structure")
#We manually went through all features and found that columns 64, 65, 66, and 67 could be useful. These represent shear stress.
# Out:
# Text(0.5, 1.0, 'Imperfect Structure')

# %% [markdown]
# # Step 5: Prepare Data for Training Model

# %%
#X will be our shear stress. Y will be our classification of the nodes.
x_data_rf = big_array[:,64:68]
y_data = big_array[:,79]
x_train_rf, x_test_rf, y_train_rf, y_test_rf = train_test_split(x_data_rf, y_data, test_size = 0.20)

#The following is the data from the test set which is not included in the train-test split
x_test_2_rf = Test_Set_Imperfect_4_1_m_2000N_arr_class[:,64:68]
y_test_2 = Test_Set_Imperfect_4_1_m_2000N_arr_class[:,79]

# %%
#Scale x data
scaler = StandardScaler()
x_train_scaled_rf = scaler.fit_transform(x_train_rf)
x_test_scaled_rf = scaler.transform(x_test_rf)
x_test_2_scaled_rf = scaler.transform(x_test_2_rf)

# %% [markdown]
# # Step 6: Train Model

# %%
rf = RandomForestClassifier()
rf.fit(x_train_scaled_rf, y_train_rf)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Step 7: Evaluate Model

# %%
#Find accuracy using data from train-test split
rf.score(x_test_scaled_rf, y_test_rf)
# Out:
# 0.9999909957770194

# %%
#What is the model's prediction for the Test Set?
y_pred_rf = rf.predict(x_test_2_scaled_rf)
rf_fit = accuracy_score(y_test_2, y_pred_rf)
print(rf_fit)
# Out:
# 1.0

# %%
#Function to find missing sections of Test Set without using model
def missing_node_array(x):
    n = len(x)
    miss = []
    for i in range (n-1):
        new_miss = x.iat[i+1, 0] - x.iat[i,0]
        if new_miss > 1:
            miss.append(x.iat[i, 0])
    return miss

#Where does the missing section of nodes begin in the Test Set
missing_node_array(Test_Set_Imperfect_4_1_m_2000N)
# Out:
# [15798]

# %%
#Actual amount of imperfect nodes in Test Set
sum(y_test_2)
# Out:
# 265.0

# %%
#Indices of imperfect nodes in Test Set according to model
imp_nodes = np.where(y_pred_rf == 1)
print(imp_nodes)
# Out:
# (array([15798, 15799, 15800, 15801, 15802, 15803, 15804, 15805, 15806,
#        15807, 15808, 15809, 15810, 15811, 15812, 15813, 15814, 15815,
#        15816, 15817, 15818, 15819, 15820, 15821, 15822, 15823, 15824,
#        15825, 15826, 15827, 15828, 15829, 15830, 15831, 15832, 15833,
#        15834, 15835, 15836, 15837, 15838, 15839, 15840, 15841, 15842,
#        15843, 15844, 15845, 15846, 15847, 15848, 15849, 15850, 15851,
#        15852, 15853, 15854, 15855, 15856, 15857, 15858, 15859, 15860,
#        15861, 15862, 15863, 15864, 15865, 15866, 15867, 15868, 15869,
#        15870, 15871, 15872, 15873, 15874, 15875, 15876, 15877, 15878,
#        15879, 15880, 15881, 15882, 15883, 15884, 15885, 15886, 15887,
#        15888, 15889, 15890, 15891, 15892, 15893, 15894, 15895, 15896,
#        15897, 15898, 15899, 15900, 15901, 15902, 15903, 15904, 15905,
#        15906, 15907, 15908, 15909, 15910, 15911, 15912, 15913, 15914,
# ...

# %%
#Amount of imperfect nodes in Test Set according to model
sum(y_pred_rf)
# Out:
# 265.0

# %% [markdown]
# ## Using Deep Learning Model

# %%
#For Deep Learning, we will use all of the data for X. Y will be our classification of the nodes.

x_test_2_dl = np.delete(Test_Set_Imperfect_4_1_m_2000N_arr_class, [12,79], axis = 1)
x_data_dl = np.delete(big_array, [12,79], axis = 1)
x_train_dl, x_test_dl, y_train_dl, y_test_dl = train_test_split(x_data_dl, y_data, test_size = 0.20)

#Scale x data
x_train_scaled_dl = scaler.fit_transform(x_train_dl)
x_test_scaled_dl = scaler.transform(x_test_dl)
x_test_2_scaled_dl = scaler.transform(x_test_2_dl)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score


model = Sequential([
    Input(shape=(x_train_scaled_dl.shape[1],)),
    Dense(512, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.4),
    Dense(256, activation='relu' , kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
optimizer = Adam(learning_rate=0.000005)
model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Step 6: Train the model
history = model.fit(x_train_scaled_dl, y_train_dl, epochs=10, batch_size=128, validation_split=0.2, verbose=2, callbacks=[early_stopping])
# Out:
# Epoch 1/10
# 2777/2777 - 27s - loss: 0.4970 - accuracy: 0.9601 - val_loss: 0.4045 - val_accuracy: 0.9891 - 27s/epoch - 10ms/step
# Epoch 2/10
# 2777/2777 - 16s - loss: 0.3378 - accuracy: 0.9889 - val_loss: 0.2703 - val_accuracy: 0.9891 - 16s/epoch - 6ms/step
# Epoch 3/10
# 2777/2777 - 16s - loss: 0.2123 - accuracy: 0.9889 - val_loss: 0.1599 - val_accuracy: 0.9891 - 16s/epoch - 6ms/step
# Epoch 4/10
# 2777/2777 - 16s - loss: 0.1231 - accuracy: 0.9889 - val_loss: 0.0909 - val_accuracy: 0.9891 - 16s/epoch - 6ms/step
# Epoch 5/10
# 2777/2777 - 16s - loss: 0.0704 - accuracy: 0.9894 - val_loss: 0.0515 - val_accuracy: 0.9953 - 16s/epoch - 6ms/step
# Epoch 6/10
# 2777/2777 - 16s - loss: 0.0410 - accuracy: 0.9936 - val_loss: 0.0306 - val_accuracy: 0.9979 - 16s/epoch - 6ms/step
# Epoch 7/10
# 2777/2777 - 16s - loss: 0.0259 - accuracy: 0.9970 - val_loss: 0.0207 - val_accuracy: 0.9985 - 16s/epoch - 6ms/step
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

# Plot loss vs. epoch
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred_proba = model.predict(x_test_scaled_dl)
y_pred_nn = (y_pred_proba > 0.5).astype(int)

# Generate and visualize the confusion matrix
cm = confusion_matrix(y_test_dl, y_pred_nn)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix for Model')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Print the confusion matrix
print(cm)
# Out:
# 3471/3471 [==============================] - 5s 2ms/step
# [[109861      1]
#  [    59   1138]]

# %%
#model.save('my_model.h5')  # Creates a HDF5 file 'my_model.h5'

# Make predictions on the test set
y_pred_proba_2 = model.predict(x_test_2_scaled_dl)
y_pred_nn_2 = (y_pred_proba_2 > 0.5).astype(int)

# Calculate the accuracy on the test set
test_accuracy = accuracy_score(y_test_2, y_pred_nn_2)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 914/914 [==============================] - 2s 2ms/step
# Test Accuracy: 0.9991445972763977

# %%
missing_nodes = np.where(y_pred_nn_2 == 1)
print(missing_nodes)
# Out:
# (array([ 1969,  1976,  1977,  1978,  2137,  2138, 15798, 15800, 15801,
#        15803, 15804, 15805, 15806, 15807, 15808, 15809, 15810, 15811,
#        15813, 15814, 15815, 15816, 15817, 15818, 15819, 15820, 15821,
#        15823, 15824, 15825, 15826, 15827, 15828, 15829, 15830, 15831,
#        15832, 15833, 15834, 15835, 15836, 15837, 15838, 15839, 15840,
#        15841, 15842, 15843, 15844, 15845, 15846, 15847, 15848, 15849,
#        15850, 15851, 15852, 15853, 15854, 15855, 15856, 15857, 15858,
#        15859, 15860, 15861, 15862, 15863, 15864, 15865, 15866, 15867,
#        15868, 15869, 15870, 15871, 15872, 15873, 15874, 15875, 15876,
#        15877, 15878, 15879, 15880, 15881, 15882, 15883, 15884, 15885,
#        15886, 15887, 15888, 15889, 15890, 15891, 15893, 15894, 15895,
#        15896, 15897, 15898, 15900, 15901, 15902, 15903, 15904, 15905,
#        15906, 15907, 15909, 15910, 15911, 15912, 15913, 15914, 15915,
# ...

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Generate and visualize the confusion matrix
cm = confusion_matrix(y_test_2, y_pred_nn_2)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix for Test Set')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Print the confusion matrix
print(cm)
# Out:
# [[28955     6]
#  [   19   246]]
